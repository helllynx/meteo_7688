# %%
import pandas as pd
import matplotlib.pyplot as plot
import numpy as np

# %%
df = pd.read_csv("data.txt", names=['time', 'temp_dht', 'temp_bmp', 'pressure', 'humidity'], header=None)
df = df[df.select_dtypes(include=[np.number]).ge(0).all(1)]

# %%
df.head()
# Out:
#      time  temp_dht  temp_bmp  pressure  humidity
# 0  178771     22.77     23.95    750.08      33.3
# 1  189202     22.89     23.95    750.04      33.4
# 2  199630     22.78     24.03    750.01      33.5
# 3  210061     22.75     23.93    750.01      32.5
# 4  220491     22.73     23.85    750.03      31.6

# %%
df.plot(y=['temp_dht', 'temp_bmp'])
# Out:
# <AxesSubplot: >

# %%
df.plot(y=['pressure'])
# Out:
# <AxesSubplot: >

# %%
df.plot(y=['humidity'])
# Out:
# <AxesSubplot: >
